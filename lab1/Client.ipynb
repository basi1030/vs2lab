# %% [markdown]
# # Running server and client in separate notebooks - client part
#
# Here we start the client. The server needs to be started first. Lets go....

# %%
import importlib
import clientserver # import from our script

# %%
importlib.reload(clientserver)
client = clientserver.Client() # Create a client instance
# Out:
# 2026-04-10 11:37:49,238 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=66, family=2, type=1, proto=0, laddr=('127.0.0.1', 40490), raddr=('127.0.0.1', 50007)>
# 2026-04-10 11:37:49,238 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=66, family=2, type=1, proto=0, laddr=('127.0.0.1', 40490), raddr=('127.0.0.1', 50007)>
# 2026-04-10 11:37:49,238 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=66, family=2, type=1, proto=0, laddr=('127.0.0.1', 40490), raddr=('127.0.0.1', 50007)>

# %%
client.get("Simi")
# Out:
# 2026-04-10 11:38:39,601 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# 2026-04-10 11:38:39,601 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# 2026-04-10 11:38:39,601 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# Simi:  +491745789846
# '+491745789846'

# %%
client.getall()
# Out:
# 2026-04-10 11:38:41,219 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# 2026-04-10 11:38:41,219 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# 2026-04-10 11:38:41,219 - vs2lab.a1_layers.clientserver.Client - INFO - Client down.
# GETALL:  {'Simi': '+491745789846', 'Joline': '+4915141212280', 'Lisa': '+49123456789'}
# "{'Simi': '+491745789846', 'Joline': '+4915141212280', 'Lisa': '+49123456789'}"

# %%
client.close()
