# %% [markdown]
# # Running server and client in separate notebooks - client part
#
# Here we start the client. The server needs to be started first. Lets go....
#
# ## Telefonauskunft – Client
#
# Dieses Notebook stellt Anfragen an den Telefonauskunft-Server.
#
# Voraussetzung:
# Der Server muss bereits laufen.
#
# Verfügbare Funktionen:
# - get(Name): Sucht eine Telefonnummer
# - getall(): Gibt alle Einträge zurück

# %%
import importlib
import clientserver # import from our script

# %%
importlib.reload(clientserver)
client = clientserver.Client() # Create a client instance
# Out:
# 2026-04-16 12:44:43,693 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=62, family=2, type=1, proto=0, laddr=('127.0.0.1', 57442), raddr=('127.0.0.1', 50007)>
# 2026-04-16 12:44:43,693 - vs2lab.a1_layers.clientserver.Client - INFO - Client connected to socket <socket.socket fd=62, family=2, type=1, proto=0, laddr=('127.0.0.1', 57442), raddr=('127.0.0.1', 50007)>

# %%
client.get("")
# Out:
# 2026-04-16 12:44:46,794 - vs2lab.a1_layers.clientserver.Client - INFO - GET-Request sent for .
# 2026-04-16 12:44:46,794 - vs2lab.a1_layers.clientserver.Client - INFO - GET-Request sent for .

# %%
client.getall()
# Out:
# 2026-04-16 12:35:22,706 - vs2lab.a1_layers.clientserver.Client - INFO - GET-Request sent for GETALL.
# 2026-04-16 12:35:22,706 - vs2lab.a1_layers.clientserver.Client - INFO - GET-Request sent for GETALL.
# 2026-04-16 12:35:22,706 - vs2lab.a1_layers.clientserver.Client - INFO - GET-Request sent for GETALL.
# 2026-04-16 12:35:22,713 - vs2lab.a1_layers.clientserver.Client - INFO - GET-Response received for GETALL.
# 2026-04-16 12:35:22,713 - vs2lab.a1_layers.clientserver.Client - INFO - GET-Response received for GETALL.
# 2026-04-16 12:35:22,713 - vs2lab.a1_layers.clientserver.Client - INFO - GET-Response received for GETALL.
# GETALL:  {'Simi': '+491745789846', 'Joline': '+4915141212280', 'Lisa': '+49123456789'}
# "{'Simi': '+491745789846', 'Joline': '+4915141212280', 'Lisa': '+49123456789'}"

# %%
client.close()
# Out:
# 2026-04-16 12:35:24,158 - vs2lab.a1_layers.clientserver.Client - INFO - Client down. Socket closed.
# 2026-04-16 12:35:24,158 - vs2lab.a1_layers.clientserver.Client - INFO - Client down. Socket closed.
# 2026-04-16 12:35:24,158 - vs2lab.a1_layers.clientserver.Client - INFO - Client down. Socket closed.
