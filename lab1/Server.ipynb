# %% [markdown]
# # Running server and client in separate notebooks - server part
# This is the first notebook we need to run in this constelation. Note that the client notebook needs to be run now in a separate window.

# %%
import importlib
import clientserver # import from our script

# %%
importlib.reload(clientserver)
server = clientserver.Server() # Create a server instance
# Out:
# 2026-04-14 13:48:01,255 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=63, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>
# 2026-04-14 13:48:01,255 - vs2lab.lab1.clientserver.Server - INFO - Server bound to socket <socket.socket fd=63, family=2, type=1, proto=0, laddr=('127.0.0.1', 50007)>

# %%
server.serve() # start server routine in the forked process
# Out:
# 2026-04-14 13:48:11,142 - vs2lab.lab1.clientserver.Server - INFO - GET-Request received for Simi.
# 2026-04-14 13:48:11,142 - vs2lab.lab1.clientserver.Server - INFO - GET-Request received for Simi.
# 2026-04-14 13:48:11,153 - vs2lab.lab1.clientserver.Server - INFO - GET-Response sent for Simi.
# 2026-04-14 13:48:11,153 - vs2lab.lab1.clientserver.Server - INFO - GET-Response sent for Simi.
# 2026-04-14 13:48:12,722 - vs2lab.lab1.clientserver.Server - INFO - GET-Request received for GETALL.
# 2026-04-14 13:48:12,722 - vs2lab.lab1.clientserver.Server - INFO - GET-Request received for GETALL.
# 2026-04-14 13:48:12,727 - vs2lab.lab1.clientserver.Server - INFO - GET-Response sent for GETALL.
# 2026-04-14 13:48:12,727 - vs2lab.lab1.clientserver.Server - INFO - GET-Response sent for GETALL.

# %% [markdown]
# Finished
